# %% [markdown]
# # ⚫ Lesson 20: Project Capstone
#
# ## 🎓 Graduation Day!
# You have completed the 20-notebook course. You now understand:
# 1.  **Physics**: Diffusion, Noise schedules.
# 2.  **Architecture**: VAE, U-Net, CLIP.
# 3.  **Control**: CFG, SDEdit, Masks.
# 4.  **Engineering**: VRAM optimization, OOM protection.
# 5.  **Training**: LoRA fine-tuning.
# 6.  **Deployment**: Gradio interfaces.
#
# ### Your Final Exam
# Your final task is to run the full application and use everything you learned to create a masterpiece.

# %%
# Run the app directly from here (or use python app.py in terminal)
# !python ../app.py

# %% [markdown]
# ## Future Learning Paths
#
# Where to go from here?
#
# 1.  **ControlNet**: Adding skeletal tracking for poses.
# 2.  **SDXL / SD3**: Newer, bigger models.
# 3.  **ComfyUI**: Node-based workflows.
#
# Thank you for learning with us!
