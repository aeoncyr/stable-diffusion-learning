# %% [markdown]
# # 🎓 Lesson 3: Interactive App
#
# Did you know you can run the full Graphical User Interface (GUI) right here in the notebook?
#
# This uses `Gradio`, a library for creating ML demos quickly. Our `app.py` is built entirely with Gradio Blocks.

# %%
import sys
import os
from pathlib import Path

project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Import the app creator function
from app import create_app

# Create the Gradio app
demo = create_app()

# Launch it inline!
demo.launch(share=False, height=900)
